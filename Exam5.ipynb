# %%
# 1. Устанавливаем Kaggle API
# !pip install kaggle

# 2. Загружаем Kaggle API ключ (ваш файл kaggle.json)
from google.colab import files
files.upload()  # выберите ваш kaggle.json

# 3. Переносим ключ в нужную папку
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# 4. Скачиваем датасет Telco Customer Churn
# !kaggle datasets download -d blastchar/telco-customer-churn

# 5. Распаковываем
# !unzip telco-customer-churn.zip
# Out:
# ...
#      <input type="file" id="files-fc5844f5-251b-4c05-a5a5-a793761fc121" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc5844f5-251b-4c05-a5a5-a793761fc121">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import auth
auth.authenticate_user()

df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# Смотрим на данные
print(df.shape)
df.head()

# Загружаем в BigQuery
project_id = 'exam-task-5'  # ваш проект
dataset_id = 'customer_churn'   # ваш датасет
table_id = 'telco_churn'

df.to_gbq(
    destination_table=f'{dataset_id}.{table_id}',
    project_id=project_id,
    if_exists='replace'
)

print("Данные загружены в BigQuery!")
# Out:
# (7043, 21)
# /tmp/ipykernel_4420/3561449284.py:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   df.to_gbq(
# 100%|██████████| 1/1 [00:00<00:00, 9597.95it/s]
# Данные загружены в BigQuery!
